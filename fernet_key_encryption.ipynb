# %%
from cryptography.hazmat.backends import default_backend
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.primitives import hashes
from cryptography.hazmat.primitives.asymmetric import padding
from cryptography.fernet import Fernet
import cryptography.fernet
import time
import os

# %%
key = Fernet.generate_key()

# %%
key
# Out:
# b'0sWGLPc6oMWQqzoqWWVMcJFVVSMCXCb9g8DtZTyJAdY='

# %%
test_path = '/home/zeefu/Desktop/'

# %%
with open(os.path.join(test_path, 'fernet_key.key'), 'wb')  as file:
    #file.seek(0)
    file.write(key)
file.close()

# %%
test_path
# Out:
# '/home/zeefu/Desktop/'

# %%
with open(os.path.join(test_path, 'fernet_key.key'), 'rb') as file:
    #file.seek(0)
    key = file.read().decode()
file.close()

key
# Out:
# '0sWGLPc6oMWQqzoqWWVMcJFVVSMCXCb9g8DtZTyJAdY='

# %%
with open(os.path.join(test_path, '0_eLsEoykT1ImBEw_L.jpg'), 'rb') as file:
    #file.seek(0)
    data = file.read()
file.close()

# %%
fernet_key = cryptography.fernet.Fernet(key)  # key variable in bytes
encrypted_content = fernet_key.encrypt(data) # in bytes

# %%
with open(os.path.join(test_path, 'Copyblogger-Copywriting-101.pdf'), 'wb') as file:
    #file.seek(0)
    file.write(encrypted_content)
file.close()

# %%
decrypted_content = fernet_key.decrypt(encrypted_content)

# %%
with open(os.path.join(test_path, 'Copyblogger-Copywriting-101_decrypted.pdf'), 'wb') as file:

    file.write(decrypted_content)
    #print(file.mode)
file.close()

# %%
message = 'hello'
r = cryptography.fernet.Fernet(key) # key is not a byte string 
encrypted_message = r.encrypt(b'data') # data to be encrpyted must be a byte string
decrypted_message = r.decrypt(encrypted_message) # decrpyted is a byte string
decrypted_message.decode()
#decrypted_message.decode()
# Out:
# 'data'

# %%
type(decrypted_content)
# Out:
# bytes

# %%
encrypted_message
# Out:
# b'gAAAAABfA7hwaCp-4S9_yx_fB9OTT4FRxfwdFElI_pxLWNs-lbnz9VQUshFJhreV2njfEYKhao9pG_ccpz4Wo6snpiIccGhs8A=='

# %%
with open('/home/zeefu/Desktop/private_key.pem', 'rb') as file:
    file.seek(0)
    data = file.read()

# %%
with open('/home/zeefu/Documents/Long Term Goals.odt', 'rb+') as file:
    file.seek(0)
    data = file.read()
file.close()

key = Fernet.generate_key()

fernet_key = cryptography.fernet.Fernet(key)

encrypted_content = fernet_key.encrypt(data)

# %%
key
# Out:
# b'VnhGVjTgRAmny5MNF5OT1DpfT2hGVhlTRd9j_2uwhsY='

# %%
with open('/home/zeefu/Desktop/Long Term Goals.odt', 'wb+') as file_2:
    file_2.seek(0)
    
    file_2.write(encrypted_content)
file_2.close()

# %%
key
# Out:
# b'VnhGVjTgRAmny5MNF5OT1DpfT2hGVhlTRd9j_2uwhsY='

# %%
with open('/home/zeefu/Desktop/Long Term Goals.odt', 'wb+') as file:
    file.seek(0)
    encrypted_content = file.read()
    decrypted_content = fernet_key.decrypt(encrypted_content)
# Out:
# ---------------------------------------------------------------------------
# InvalidToken                              Traceback (most recent call last)
# <ipython-input-297-c53c8ac9ed3d> in <module>
#       3     file.seek(0)
#       4     encrypted_content = file.read()
# ----> 5     decrypted_content = fernet_key.decrypt(encrypted_content)
#
# ~/anaconda3/lib/python3.7/site-packages/cryptography/fernet.py in decrypt(self, token, ttl)
#      72
#      73     def decrypt(self, token, ttl=None):
# ---> 74         timestamp, data = Fernet._get_unverified_token_data(token)
#      75         return self._decrypt_data(data, timestamp, ttl)
#      76
#
# ~/anaconda3/lib/python3.7/site-packages/cryptography/fernet.py in _get_unverified_token_data(token)
#      92
#      93         if not data or six.indexbytes(data, 0) != 0x80:
# ---> 94             raise InvalidToken
#      95
#      96         try:
#
# InvalidToken:

# %%
private_key_password = 'test'

# %%
with open('/home/zeefu/Desktop/fernet_1.key', 'rb') as file:
    file.seek(0)
    fernet_key_read = file.read()

# %%
with open('/home/zeefu/Desktop/private_key_1.pem', 'rb') as key_file:
    
    private_key = serialization.load_pem_private_key(
                key_file.read(),
                password = b'%b' % private_key_password.encode('utf-8'),
                backend = default_backend()
                        )
    decrypted_bytes = private_key.decrypt(fernet_key_read, padding.OAEP(
                                        mgf=padding.MGF1(algorithm=hashes.SHA256()),
                                        algorithm=hashes.SHA256(),
                                        label=None
                        )
    )

# %%
decrypted_bytes.decode()
# Out:
# 'npe90VKXAHzvGCbKu3V1cbOEHTDgwLyoCYslcbgU4L0='

# %%
os.__dict__
# Out:
# {'__name__': 'os',
# ...

# %%
# Out:
# b'-----BEGIN ENCRYPTED PRIVATE KEY-----\\nN+1B3nbXCJTdol85VNmIxlcDCtJyQZrUC
# ...

# %%
with open(os.path.join(test_path, '/home/zeefu/Desktop/0_eLsEoykT1ImBEw_L.jpg'), 'rb') as file:
    #file.seek(0)
    data = file.read()
file.close()

# %%
data
# Out:
# b'\xff\xd8\xff\xdb\x00\x84\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc0\x00\x11\x08\x02\x80\x03\xc0\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x01\xa2\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8
# ...
